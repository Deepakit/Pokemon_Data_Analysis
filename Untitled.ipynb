# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pokemon=pd.read_csv("pokemon.csv")
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost      ...       percentage_male  \
# 0             2.0            1.0      ...                  88.1
# ...

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
# abilities            801 non-null object
# against_bug          801 non-null float64
# against_dark         801 non-null float64
# against_dragon       801 non-null float64
# against_electric     801 non-null float64
# against_fairy        801 non-null float64
# against_fight        801 non-null float64
# against_fire         801 non-null float64
# against_flying       801 non-null float64
# against_ghost        801 non-null float64
# against_grass        801 non-null float64
# against_ground       801 non-null float64
# against_ice          801 non-null float64
# against_normal       801 non-null float64
# against_poison       801 non-null float64
# against_psychic      801 non-null float64
# against_rock         801 non-null float64
# against_steel        801 non-null float64
# against_water        801 non-null float64
# attack               801 non-null int64
# ...

# %%
pokemon.isnull().sum()
# Out:
# abilities              0
# against_bug            0
# against_dark           0
# against_dragon         0
# against_electric       0
# against_fairy          0
# against_fight          0
# against_fire           0
# against_flying         0
# against_ghost          0
# against_grass          0
# against_ground         0
# against_ice            0
# against_normal         0
# against_poison         0
# against_psychic        0
# against_rock           0
# against_steel          0
# against_water          0
# attack                 0
# base_egg_steps         0
# base_happiness         0
# base_total             0
# capture_rate           0
# classfication          0
# defense                0
# experience_growth      0
# height_m              20
# hp                     0
# japanese_name          0
# name                   0
# percentage_male       98
# pokedex_number         0
# sp_attack              0
# sp_defense             0
# speed                  0
# type1                  0
# ...

# %%
pokemon[pokemon.duplicated('name',keep=False)].head()
# Out:
# Empty DataFrame
# Columns: [abilities, against_bug, against_dark, against_dragon, against_electric, against_fairy, against_fight, against_fire, against_flying, against_ghost, against_grass, against_ground, against_ice, against_normal, against_poison, against_psychic, against_rock, against_steel, against_water, attack, base_egg_steps, base_happiness, base_total, capture_rate, classfication, defense, experience_growth, height_m, hp, japanese_name, name, percentage_male, pokedex_number, sp_attack, sp_defense, speed, type1, type2, weight_kg, generation, is_legendary]
# Index: []
#
# [0 rows x 41 columns]

# %%
df=pokemon[pokemon['height_m'].isnull()]
print(df['generation'])
df=pokemon[pokemon['weight_kg'].isnull()]
print(df['generation'])
# Out:
# 18     1
# 19     1
# 25     1
# 26     1
# 27     1
# 36     1
# 37     1
# 49     1
# 50     1
# 51     1
# 52     1
# 73     1
# 74     1
# 75     1
# 87     1
# 88     1
# 102    1
# 104    1
# 719    6
# 744    7
# Name: generation, dtype: int64
# 18     1
# 19     1
# 25     1
# 26     1
# 27     1
# 36     1
# 37     1
# 49     1
# 50     1
# 51     1
# 52     1
# 73     1
# 74     1
# 75     1
# 87     1
# 88     1
# 102    1
# 104    1
# 719    6
# 744    7
# Name: generation, dtype: int64

# %%
pk=pokemon.groupby('generation')['height_m'].mean()


wk=pokemon.groupby('generation')['weight_kg'].mean()


#Height
pokemon.loc[pokemon['generation']==1,'height_m']=1.24
pokemon.loc[pokemon['generation']==6,'height_m']=1.09
pokemon.loc[pokemon['generation']==7,'height_m']=1.28

#Weight
pokemon.loc[pokemon['generation']==1,'weight_kg']=45.82
pokemon.loc[pokemon['generation']==6,'weight_kg']=52.225
pokemon.loc[pokemon['generation']==7,'weight_kg']=98.30

#Percentage_male
pokemon.loc[pokemon['percentage_male'].isnull(),'percentage_male']=0

#Type_2
pokemon['type2'].fillna(pokemon['type1'],inplace=True)

pokemon.isnull().sum()
# Out:
# abilities            0
# against_bug          0
# against_dark         0
# against_dragon       0
# against_electric     0
# against_fairy        0
# against_fight        0
# against_fire         0
# against_flying       0
# against_ghost        0
# against_grass        0
# against_ground       0
# against_ice          0
# against_normal       0
# against_poison       0
# against_psychic      0
# against_rock         0
# against_steel        0
# against_water        0
# attack               0
# base_egg_steps       0
# base_happiness       0
# base_total           0
# capture_rate         0
# classfication        0
# defense              0
# experience_growth    0
# height_m             0
# hp                   0
# japanese_name        0
# name                 0
# percentage_male      0
# pokedex_number       0
# sp_attack            0
# sp_defense           0
# speed                0
# type1                0
# type2                0
# weight_kg            0
# generation           0
# ...

# %%
pokemon.columns.unique
# Out:
# <bound method Index.unique of Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')>

# %%
del(pokemon['base_total'])
del(pokemon['japanese_name'])

# %%
pokemon.dtypes
# Out:
# abilities             object
# against_bug          float64
# against_dark         float64
# against_dragon       float64
# against_electric     float64
# against_fairy        float64
# against_fight        float64
# against_fire         float64
# against_flying       float64
# against_ghost        float64
# against_grass        float64
# against_ground       float64
# against_ice          float64
# against_normal       float64
# against_poison       float64
# against_psychic      float64
# against_rock         float64
# against_steel        float64
# against_water        float64
# attack                 int64
# base_egg_steps         int64
# base_happiness         int64
# capture_rate          object
# classfication         object
# defense                int64
# experience_growth      int64
# height_m             float64
# hp                     int64
# name                  object
# percentage_male      float64
# pokedex_number         int64
# sp_attack              int64
# ...

# %%
sns.catplot(x='generation',data=pokemon,kind='count')
plt.title('Pokemons in Generations')
plt.show()

# %%
pokemon['Against_total']=pokemon.iloc[:,1:19].sum(axis=1)
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost      ...        pokedex_number  sp_attack  \
# ...

# %%
print(pokemon['type1'].value_counts())
pokemon['type2'].value_counts()
# Out:
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# ground       32
# poison       32
# dark         29
# fighting     28
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: type1, dtype: int64
# flying      96
# water       78
# normal      65
# psychic     64
# grass       57
# fighting    47
# poison      47
# fairy       45
# ground      44
# fire        40
# electric    35
# dark        30
# dragon      29
# ice         27
# steel       26
# rock        25
# ghost       23
# bug         23
# Name: type2, dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.set_style("darkgrid")
sns.countplot(x='type1',data=pokemon,hue='generation')
plt.xticks(rotation=90)
plt.title("Type-1 Pokemon")
plt.show()
plt.figure(figsize=(16,10))
sns.countplot(x='type1',data=pokemon)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='type2',data=pokemon)
plt.xticks(rotation=90)
plt.show()

sns.factorplot(x='generation',kind='count',data=pokemon,col='type2',col_wrap=3)
plt.show()
# Out:
# C:\Users\deepasharma\AppData\Roaming\Python\Python36\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
pokemon.dtypes
# Out:
# abilities             object
# against_bug          float64
# against_dark         float64
# against_dragon       float64
# against_electric     float64
# against_fairy        float64
# against_fight        float64
# against_fire         float64
# against_flying       float64
# against_ghost        float64
# against_grass        float64
# against_ground       float64
# against_ice          float64
# against_normal       float64
# against_poison       float64
# against_psychic      float64
# against_rock         float64
# against_steel        float64
# against_water        float64
# attack                 int64
# base_egg_steps         int64
# base_happiness         int64
# capture_rate          object
# classfication         object
# defense                int64
# experience_growth      int64
# height_m             float64
# hp                     int64
# name                  object
# percentage_male      float64
# pokedex_number         int64
# sp_attack              int64
# ...

# %%
pokemon['strong_total']=pokemon['attack']+pokemon['defense']+pokemon['sp_attack']+pokemon['sp_defense']+pokemon['speed']
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost      ...       sp_attack  sp_defense  speed  \
# ...

# %%
strong_df=pokemon[['generation','Against_total','strong_total','type1','type2']]
strong_df['generation'].value_counts()
# Out:
# 5    156
# 1    151
# 3    135
# 4    107
# 2    100
# 7     80
# 6     72
# Name: generation, dtype: int64

# %%
strong_df.describe()
# Out:
#        generation  Against_total  strong_total
# count  801.000000     801.000000    801.000000
# mean     3.690387      19.044007    359.418227
# std      1.930420       1.905506    104.802474
# min      1.000000      13.250000    120.000000
# 25%      2.000000      18.000000    270.000000
# 50%      4.000000      18.750000    360.000000
# 75%      5.000000      20.000000    429.000000
# max      7.000000      26.000000    675.000000

# %%
strong_df.groupby('generation')[('Against_total','strong_total')].mean().sort_values(by=['Against_total','strong_total'],ascending=(True,False)).reset_index()
# Out:
#    generation  Against_total  strong_total
# 0           7      18.937500    377.587500
# 1           1      19.003311    351.907285
# 2           4      19.004673    378.074766
# 3           5      19.043269    356.724359
# 4           2      19.080000    342.200000
# 5           6      19.090278    366.500000
# 6           3      19.133333    354.355556

# %% [markdown]
# We can see Generation 7 has strongest type of pokemon Generation 3 has weakest type of Pokemon.

# %%
strong_df[('type1')].value_counts()
# Out:
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# ground       32
# poison       32
# dark         29
# fighting     28
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: type1, dtype: int64

# %%
strong_df.groupby(['type1'])[('Against_total','strong_total')].mean().sort_values(by=['Against_total','strong_total'],ascending=(True,False)).reset_index()
# Out:
#        type1  Against_total  strong_total
# 0      steel      15.458333    424.791667
# 1   electric      17.192308    375.641026
# 2      ghost      17.592593    371.333333
# 3      fairy      17.611111    353.222222
# 4     poison      17.703125    333.968750
# 5     normal      18.080952    324.571429
# 6       fire      18.235577    381.903846
# 7      water      18.285088    356.570175
# 8       dark      19.362069    377.206897
# 9   fighting      19.535714    343.392857
# 10    ground      19.609375    352.906250
# 11    flying      19.666667    385.333333
# 12    dragon      19.787037    442.925926
# 13   psychic      19.919811    388.320755
# 14       bug      20.045139    323.708333
# 15     grass      20.919872    347.217949
# 16       ice      21.489130    361.521739
# 17      rock      21.527778    380.933333

# %% [markdown]
# Hence, Steel gives us strongest type of Pokemon and Rock is weakest.

# %%
pokemon.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'capture_rate', 'classfication',
#        'defense', 'experience_growth', 'height_m', 'hp', 'name',
#        'percentage_male', 'pokedex_number', 'sp_attack', 'sp_defense', 'speed',
#        'type1', 'type2', 'weight_kg', 'generation', 'is_legendary',
#        'Against_total', 'strong_total'],
#       dtype='object')

# %%
physical_df=pokemon[['height_m','weight_kg','strong_total','Against_total']]

# %%
corr=physical_df.corr()
print(corr)
c=physical_df['height_m']
d=physical_df['strong_total']

cor=c.corr(d)
cor

sns.heatmap(
physical_df.corr(),
    linewidths=1,
    cmap='RdYlBu_r'
)
# Out:
#                height_m  weight_kg  strong_total  Against_total
# height_m       1.000000   0.653096      0.405794      -0.035452
# weight_kg      0.653096   1.000000      0.426457      -0.040271
# strong_total   0.405794   0.426457      1.000000      -0.020373
# Against_total -0.035452  -0.040271     -0.020373       1.000000

# %% [markdown]
# So we see there is no correaltion between Physical stats and combat stats.
